# %%
import pandas as pd

# %%
#same dataset
rating = pd.read_csv("ratings.csv")
movie = pd.read_csv("movies_metadata.csv")
#our main movie dataset
main_movie = pd.read_csv("movies.csv")
# Out:
# /tmp/ipykernel_298/4184412337.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie = pd.read_csv("movies_metadata.csv")

# %%
#dropping unnecessary columns, including only the title and id so it can be merged
rating.drop(columns=["timestamp"], inplace=True)
movie = movie[["original_title", "id"]]

# %%
#dropping all NaN values
rating.dropna(inplace=True)
movie.dropna(inplace=True)

# %%
rating["movieId"] = rating["movieId"].astype(str)

# %%
#merging rating and movie datasets
combined_data = pd.merge(rating, movie, left_on="movieId", right_on="id", how="left")

# %%
combined_data.dropna(inplace=True)
combined_data
# Out:
#           userId movieId  rating           original_title    id
# 0              1     110     1.0   Trois couleurs : Rouge   110
# 1              1     147     4.5   Les Quatre Cents Coups   147
# 2              1     858     5.0     Sleepless in Seattle   858
# 4              1    1246     5.0             Rocky Balboa  1246
# 5              1    1968     4.0            Fools Rush In  1968
# ...          ...     ...     ...                      ...   ...
# 17664312  183195    2605     3.0            Short Circuit  2605
# 17664315  183195    2692     4.0           Der rote Elvis  2692
# 17664316  183195    2694     2.0          Tuya de hun shi  2694
# 17664322  183195    2722     2.0  El otro lado de la cama  2722
# 17664324  183195    2762     3.0       Young and Innocent  2762
#
# [7761381 rows x 5 columns]

# %%
#dropping our redundant movieid/id column
combined_data.drop(columns=['id'], inplace=True)

# %%
#renaming our 'original_title' column because it also exists in main_movie dataset
combined_data.rename(columns={'original_title': 'com_title'}, inplace=True)
combined_data
# Out:
#           userId movieId  rating                com_title
# 0              1     110     1.0   Trois couleurs : Rouge
# 1              1     147     4.5   Les Quatre Cents Coups
# 2              1     858     5.0     Sleepless in Seattle
# 4              1    1246     5.0             Rocky Balboa
# 5              1    1968     4.0            Fools Rush In
# ...          ...     ...     ...                      ...
# 17664312  183195    2605     3.0            Short Circuit
# 17664315  183195    2692     4.0           Der rote Elvis
# 17664316  183195    2694     2.0          Tuya de hun shi
# 17664322  183195    2722     2.0  El otro lado de la cama
# 17664324  183195    2762     3.0       Young and Innocent
#
# [7761381 rows x 4 columns]

# %%
#merge movies from our main movie dataset and combined dataset 
main_movie['title'] = main_movie['title'].str.strip().str.lower()
combined_data['com_title'] = combined_data['com_title'].str.strip().str.lower()

final_data = pd.merge(combined_data, main_movie, left_on='com_title', right_on='title', how='left')

# %%
#showing that merging indeed combined the same titles
final_data_new = final_data.drop_duplicates(subset='title')
final_data_new[['title', 'com_title']]
# Out:
#                          title               com_title
# 0                          NaN  trois couleurs : rouge
# 2         sleepless in seattle    sleepless in seattle
# 3                 rocky balboa            rocky balboa
# 4                fools rush in           fools rush in
# 6           young and innocent      young and innocent
# ...                        ...                     ...
# 17372867             prototype               prototype
# 17398029             galgameth               galgameth
# 17398030  eye of the hurricane    eye of the hurricane
# 17526928               the bay                 the bay
# 17534657   he who gets slapped     he who gets slapped
#
# [5030 rows x 2 columns]

# %%
#dropping our redundant com_title/title column
final_data.drop(columns=['com_title'], inplace=True)
final_data
# Out:
#           userId movieId  rating        id                 title  \
# 0              1     110     1.0       NaN                   NaN
# 1              1     147     4.5       NaN                   NaN
# 2              1     858     5.0     858.0  sleepless in seattle
# 3              1    1246     5.0    1246.0          rocky balboa
# 4              1    1968     4.0    1968.0         fools rush in
# ...          ...     ...     ...       ...                   ...
# 17596762  183195    2692     4.0       NaN                   NaN
# 17596763  183195    2694     2.0       NaN                   NaN
# 17596764  183195    2722     2.0       NaN                   NaN
# 17596765  183195    2762     3.0    2762.0    young and innocent
# 17596766  183195    2762     3.0  486564.0    young and innocent
#
#                           genres original_language  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2           Comedy-Drama-Romance                en
# 3                          Drama                en
# 4           Comedy-Drama-Romance                en
# ...                          ...               ...
# 17596762                     NaN               NaN
# 17596763                     NaN               NaN
# 17596764                     NaN               NaN
# 17596765  Crime-Romance-Thriller                en
# 17596766                     NaN                en
#
#                                                    overview  popularity  \
# 0                                                       NaN         NaN
# 1                                                       NaN         NaN
# 2         When Sam Baldwin's wife dies he is left to bri...      16.927
# 3         His Wife is dead and his Son hates him but thi...      37.268
# 4         After a one night stand with Alex Isabel reali...      13.876
# ...                                                     ...         ...
# 17596762                                                NaN         NaN
# 17596763                                                NaN         NaN
# 17596764                                                NaN         NaN
# 17596765  Robert Tisdall finds on the beach the corpse o...       7.523
# 17596766  Deceived by the scruffy ginger counselor who’s...       0.600
#
#                                        production_companies  ... runtime  \
# 0                                                       NaN  ...     NaN
# 1                                                       NaN  ...     NaN
# 2                                          TriStar Pictures  ...   105.0
# 3         Metro-Goldwyn-Mayer-Columbia Pictures-Revoluti...  ...   101.0
# 4                                         Columbia Pictures  ...   109.0
# ...                                                     ...  ...     ...
# 17596762                                                NaN  ...     NaN
# 17596763                                                NaN  ...     NaN
# 17596764                                                NaN  ...     NaN
# 17596765                Gaumont-British Picture Corporation  ...    83.0
# 17596766                                                NaN  ...    85.0
#
#             status                                            tagline  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2         Released  What if someone you never met, someone you nev...
# 3         Released                      It ain't over 'til it's over.
# 4         Released  What if finding the love of your life meant ch...
# ...            ...                                                ...
# 17596762       NaN                                                NaN
# 17596763       NaN                                                NaN
# 17596764       NaN                                                NaN
# 17596765  Released                   A romantic murder-mystery drama!
# 17596766  Released                                                NaN
#
#           vote_average vote_count  \
# 0                  NaN        NaN
# 1                  NaN        NaN
# 2                  6.7     1988.0
# 3                  6.9     3248.0
# 4                  6.4      445.0
# ...                ...        ...
# 17596762           NaN        NaN
# 17596763           NaN        NaN
# 17596764           NaN        NaN
# 17596765           6.6      196.0
# 17596766           0.0        0.0
#
#                                                     credits  \
# 0                                                       NaN
# 1                                                       NaN
# 2         Tom Hanks-Meg Ryan-Bill Pullman-Ross Malinger-...
# 3         Sylvester Stallone-Burt Young-Antonio Tarver-G...
# 4         Matthew Perry-Salma Hayek-Jon Tenney-Carlos Gó...
# ...                                                     ...
# 17596762                                                NaN
# 17596763                                                NaN
# 17596764                                                NaN
# 17596765  Nova Pilbeam-Derrick De Marney-Percy Marmont-E...
# 17596766                                                NaN
#
#                                                    keywords  \
# 0                                                       NaN
# 1                                                       NaN
# 2         holiday-loss of loved one-lovesickness-journal...
# 3         philadelphia pennsylvania-transporter-love of ...
# 4          waitress-culture clash-pregnancy-romantic comedy
# ...                                                     ...
# 17596762                                                NaN
# 17596763                                                NaN
# 17596764                                                NaN
# 17596765  based on novel or book-country house-birthday ...
# 17596766                                                NaN
#
#                                poster_path                     backdrop_path  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
# 2         /iLWsLVrfkFvOXOG9PbUAYg7AK3E.jpg  /fROgQIALHJEmayqLITFHhOMW3ef.jpg
# 3         /xUylDspiTKU3cYzZNeLsN8Krv12.jpg  /9mwMaNeeqPXJviKk2UKLxFm9vUW.jpg
# 4         /tcRaMjWoF8K7h1LqOH7FOOLRQ3e.jpg  /9f5wCpkbbEtqEUQU9UJGV3zQEyz.jpg
# ...                                    ...                               ...
# 17596762                               NaN                               NaN
# 17596763                               NaN                               NaN
# 17596764                               NaN                               NaN
# 17596765  /knc0wcxarPM6Qy3uOm1RV38JGzS.jpg  /4Nuu5vKY7LuBVLxn9uV4aDWNOyP.jpg
# 17596766  /dH6uLakOA1X8c8z3vpmUcUE1Pyr.jpg                               NaN
#
#                                             recommendations
# 0                                                       NaN
# 1                                                       NaN
# 2         9489-64899-109040-2280-4560-11287-6951-2619-19...
# 3         1375-1367-1371-1374-1366-312221-1370-7555-1369...
# 4         953300-1439-10399-825808-58232-11846-526019-56...
# ...                                                     ...
# 17596762                                                NaN
# 17596763                                                NaN
# 17596764                                                NaN
# 17596765  21734-260-303-11462-940-573-701-2761-506-12684...
# 17596766                                                NaN
#
# [17596767 rows x 23 columns]
